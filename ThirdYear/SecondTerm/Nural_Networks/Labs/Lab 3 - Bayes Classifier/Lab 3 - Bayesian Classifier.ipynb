# %% [markdown]
# # Bayesian Classifier
# In this lab, you will implement and assess the performance of the Bayesian Classifier.
#
# ## Lab Instructions:
# 1. Read the explanation above each requirement very well
# 2. Read the requirement very well before jumping into the code.
# 3. Some requirements have essay questions in them, make sure you do NOT miss them.
# 4. PLEASE Read the hints! They are clear and made to help you complete the requirement as fast as you should

# %%
#### always keep all your imports in the first cell ####
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import csv
import math
import pandas as pd

# %matplotlib qt

# %% [markdown]
# ## Requirement
#
# In this requirement, you will build the Bayesian Classifier and test its performance.
#
# You are provided with a data file **data1.csv** containing list of points and their corresponding classes. The format of the data files is shown in the table below.
#
# | |Class|Feature 1|Feature 1|
# |-|-|-|-|
# |Point#1|1|0.271633|-2.93224|
# |Point#2|1|7.020786|-1.98966|
# |Point#3|1|2.901827|-0.91291|
#
#
# You are also provided with a test data file **test_data.csv**. The file contains test points that are unlabelled (i.e. the class to which they belong is unknown).

# %%
# TODO [1] : Read the file 'data1.csv' into the variable data.
# data contains the training data together with labelled classes.
def read_data(file_name):
    ## HINT 1: How is the data ordered in the file?
    ## HINT 2: Do you need to cast the data you read from the file?
    data = pd.read_csv(file_name, header=None)
    return data

# %%
def read_test_data():
    
    # TODO [2.A]: Read the file 'test_data.csv' into the variable test_data
    # test_data contains the unlabelled test class.
    ## HINT: Do you need to cast the data you read from the file?

    test_data = read_data('test_data.csv')
    
    # TODO [2.B]: Read the file 'test_data_true.csv' into the variable test_data_true
    # test_data_true contains the actual classes of the test instances, which you will compare
    # against your predicted classes.
    ## HINT: Do you need to cast the data you read from the file?

    test_data_true = read_data('test_data_true.csv')
    print(test_data_true)
    return test_data, test_data_true

# %% [markdown]
# ### Machine Learning Terminlology
# Machine learning problems use common termonology (names and notiations) to refer to certain things. It is useful to use this termonology throughout your code to make it readable.
#
# | | |
# |:-|:--- |
# |$M$:|A scalar; represents the number of training points in the training set.|
# |$K$:|A scalar; represents the number of test points in the test set.|
# |$N$:|A scalar; represents the number of features of training set/test set (dimensionality of data).|
# |$X$:|A numpy array of shape $(M \times N)$ containing the training data **without** its labels, where $M$ is the number of training points and $N$ is the number of features in the dataset (or dimensionality of features). <br/> Each element in $X$ is a tuple $(X_1, X_2, \dots, X_N)$ where $N$ is the number of features in the dataset.|
# |$X_{test}$:| A numpy array of shape $(K \times N)$ containing the test data, where $K$ is the number of test points and $N$ is the number of features in the dataset (or dimensionality of features). <br/> Each element in $X_{test}$ is a tuple $(X_1, X_2, \dots, X_N)$ where $N$ is the number of features in the dataset. <br/> The number of columns in $X_{test}$ is equal to the number of columns in $X$ (because they have the same number of features). However, the number of rows in $X_{test}$ is different to the number of rows in $X$.|
# |**$Y$:| A numpy array of shape $(M \times 1)$ containing the labels of the training data. Each row in $Y$ corresponds to the label of the training point in $X$.<br/> For example, $Y[j]$ corresponds to the label of the training point $X[j]$ where $0<=j<M$.|

# %%
# TODO [3]: Fill the values of M, K, N, X, XTest, and Y respectively.
# Do not fill them manually (i.e. do not set N = 3). They should be generic for any input file.  
training_data = read_data('data1.csv')
test_data, test_data_true = read_test_data()

numClasses = 3 
M = training_data.shape[0] # number of training instances 
N = training_data.shape[1] -1  # number of features
K = test_data.shape[0]# number of test points -> homa dol el ana bdkhlhom 3la el model
X = np.array(training_data.iloc[:,1:]) # training data
X_Test = np.array(test_data.iloc[:,:]) # test data
Y = np.array(training_data.iloc[:,:1]) # labels of the training data
# Out:
#        0
# 0    3.0
# 1    1.0
# 2    2.0
# 3    3.0
# 4    3.0
# ..   ...
# 445  3.0
# 446  3.0
# 447  2.0
# 448  3.0
# 449  3.0
#
# [450 rows x 1 columns]

# %%
# TODO [4]: Draw a scatter plot for traning data, where each class is coloured by the colour corresponding 
#           to its index in the colors array.
# Class 1 should be coloured in red, Class 2 should be coloured in green, and Class 3 should be coloured in blue.
# Hint: We have done a similar plot in the previous lab. What operation do we need to select training data 
#       belonging to a certain class?

colors = ['r', 'g', 'b']

for i in range(0,3):
    # the condition here is that we plot depending on the label, Y contains our labels, so, if Y[:, 0] == 1 for example,
    # then this means that we are plotting the fisrt class.
    # the scatter function takes the x and y coordinates, which in our data are the elements in the X matrix, so 
    # on x axis we plot the first column of X, and on the y axis we plot the second column of X.
    plt.scatter (X[Y[:,0]==i + 1,0], X[Y[:,0]==i + 1,1], c=colors[i], label='Class' + str(i+1))
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# #### What do you notice about the plot? (Write everything you can think of)
# 1. the data is not too much noisy.
# 2. the data is not linearly separable. ( or we can say to separate them we need to use 2 lines.)
#     one horizontal line, so if the data is above the line we can classify it as class 2, and then we need another line
#     which will be separating the red from the green and blue \ then if the data is on the left of that line, we can classify
#     it as class 1, and if it is on the right of that line, we can classify it as class 3.
# 3. the data is not balanced, as the probabilty of getting class 1 is highest probabilty then class  2 then class 3 with the least probabilty.
# 4. the data is not too much skewed, as we can see that the data of class 1 is not skewed to the left or right,       and the same for class 2 and 3
# 5. no outliers, as we can see that the data is not too much spreaded, and the data is not too much far from the mean.

# %% [markdown]
# ### Bayesian Classifier
# The Bayesian Classifier calculates the probability of the test point belonging to each class, then the class with highest probability is assigned to the test point.
#
# Classification of $x_{test}$ = $argmax_{i} P\big(C_i|x_{test}\big)$ = $argmax_{i} P(x|C_i) * P(C_i)$
#
# * $P(C_i|x_{test})$: Posterior probability
# * $P(x|C_i)$: Class-conditional probability (or distribution)
# * $P(C_i)$: Class apriori probability
#
# **Note that** $P(C_i|x_{test}) \neq P(x_{test}|C_i) * P(C_i)$. Instead,  $P(C_i|x_{test}) = \frac{P(x_{test}|C_i) * P(C_i)}{P(x_{test})}$. However, when we compare multiple classes, the denominator $P(x_{test})$ is independent of the class $i$ and can be regarded as normalizing factor.
#
# **We start by** computing statistical parameters about each class from the data.
#
# For each class, we are interested in **three** parameters that will be used for calculating the Gaussian class-conditional distribution and the posterior probability.
#
# These parameters are:
#
# |||
# |:-|:-|
# |**Class Apriori Probability: ($P_C$)**| A scalar; the probability of class occurence (how frequent this class appears in the training data)|
# |**Class Mean: ($\mu$)**| A vector of shape $(N \times 1)$, it is the expected value (mean) calculated from the training points of each class.|
# |**Class Covariance Matrix: ($\Sigma$)**| A square symmetric matrix of shape $(N \times N)$ representing the covariances between all the feature calculated from the training points of the class. <br/> For example: Matrix element $\sigma^2_{12}$ is the covariance between the 1st and the 2nd features|

# %% [markdown]
# ### Algorithms
#
# #### 1. Evaluating the probability of each class
# 1.  to evaluate the mean so we will iterate over the Y(which contains the label for the classes.)
# 2. if it was == 1 so we will increment the sum of class1 and so on
# 3. at the least we will divide by M (which is the number of the training data)
# #### 2. Evaluating the mean of each class.
# 1. iterate over Y and if it was equal to the classIndex(the loop index) then we have the same index in the X, so we will sum the values in each feature, and then divide by the number of elements in each class.
# #### 3. Evaluating the covariance
# 1. iterating over each class
# 2. getting the covariance of each feature with respect to the other one.

# %%
pClasses = [] # A list of size (numClasses, 1) containing the a priori probabilities of each class in the training set.

estimate_means = [] # A numpy array of size (numClasses, N) containing the mean points of each class in the training set. 
                    # HINT: USE NP.MEAN

estimate_covariances = [] # A numpy array of size (numClasses, N, N) containing the covariance matrices of each class in the training set.
                          # HINT: USE NP.COV (Pay attenention for what it takes as an argument)

#separating the features out to simplify the logic in the loop. 
classFeatures =[]
for i in range (numClasses): # O(numOfClasses)
    classFeatures.append(X[Y[: , 0] == i+1])
classFeatures = np.array(classFeatures)

for classIndex in range(numClasses):
    # TODO [5]: Estimate the parameters of the Gaussian distributions of the given classes.
    # Fill pClasses, estimate_means, and estimate_covariances in this part 
    # Your code should be vectorized WITHOUT USING A SINGLE FOR LOOP. 
    pClasses.append(np.round(np.sum (Y == classIndex +1) / M, 8))
    estimate_means.append((np.sum(classFeatures[classIndex][0]) / classFeatures[classIndex][0].shape[0],
                                                np.sum(classFeatures[classIndex][1]) / classFeatures[classIndex][1].shape[0]))
    estimate_covariances.append(np.cov(classFeatures[classIndex], rowvar=False)) # or we can use the Transpose and use rowvar el True, same operation :()
    # estimate_covariances.append(np.cov(classFeatures[classIndex].T, rowvar=True)) # or we can use the Transpose and use rowvar el True, same operation :()
estimate_means = np.array(estimate_means)
estimate_covariances = np.array(estimate_covariances)
# Out:
# C:\Users\20115\AppData\Local\Temp\ipykernel_16740\313011679.py:13: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   classFeatures = np.array(classFeatures)

# %% [markdown]
# ## numpy.cov ()
# > numpy.cov(m, y=None, rowvar=True, bias=False, ddof=None, fweights=None, aweights=None, *, dtype=None)
#
# Estimate a covariance matrix, given data and weights.
#
# Covariance indicates the level to which two variables vary together. If we examine N-dimensional samples, X = [x1, x2, ... , xn]^(T)
# , then the covariance matrix element Ci,j is the covariance of Xi and Xj. The element Ci,i is the variance of Xi.
#
# See the notes for an outline of the algorithm.
#
# Parameters:
#
#     m: array_like
#
#         A 1-D or 2-D array containing multiple variables and observations. Each row of m represents a variable, and each column a single observation of all those variables. Also see rowvar below.
#     y: array_like, optional
#
#         An additional set of variables and observations. y has the same form as that of m.
#     rowvarbool, optional
#
#         If rowvar is True (default), then each row represents a variable, with observations in the columns. Otherwise, the relationship is transposed: each column represents a variable, while the rows contain observations.
#     biasbool, optional
#
#         Default normalization (False) is by (N - 1), where N is the number of observations given (unbiased estimate). If bias is True, then normalization is by N. These values can be overridden by using the keyword ddof in numpy versions >= 1.5.

# %%
### Test your implementation ###
### DO NOT CHANGE THIS CODE ###
assert len(pClasses) == numClasses,\
        'Incorrect class apriori probability list, it should be of length {}'.format(len(pClasses))
assert np.sum(pClasses)==1,\
        'Sum of apriori probabilities should be 1, found {}'.format(np.sum(pClasses))

assert estimate_means.shape == (numClasses, N),\
        'Incorrect estimated means, it should be of shape {}, but found {}'.format((numClasses, N), estimate_means.shape)
assert estimate_covariances.shape == (numClasses, N, N),\
        'Incorrect estimate covariance matrices, it should be of shape {}'.format((numClasses, N, N))

# %% [markdown]
# **The second step** in the classifier is to calculate the class-conditional density using the Gaussian destribution:
#
# $P(x|C_i) = \mathcal{N}(x; \mu_i, \Sigma_i) = \frac{1}{(2\pi)^{\frac{N}{2}}|\Sigma_i|^{\frac{1}{2}}} exp\big(\frac{-1}{2}(x-\mu_i)^T\Sigma^{-1}_{i}(x-\mu_i)\big)$

# %%
# TODO 6: Implement the multivariate normal gaussian distribution with parameters mu and sigma, and return the
#  value in prob.
def multivariate_normal_gaussian(X, mu, sigma):
    prob = (1/ ((2 * np.pi)**(X.size/2) * np.linalg.det(sigma)**(1/2))) * np.exp(-1/2 * (X-mu).T @ np.linalg.inv(sigma) @ (X-mu)) # @ is the matrix multiplication
    return prob

# %%
### Test your implementation ###
### DO NOT CHANGE THIS CODE ###
np.random.seed(90)
assertion_x = np.random.rand(3).reshape(-1,1)
assertion_mu = np.random.rand(3).reshape(-1,1)
assertion_sigma = np.random.rand(9).reshape(3,3)
assertion_probability = multivariate_normal_gaussian(assertion_x, assertion_mu, assertion_sigma)[0][0]
assertion_probability = round(assertion_probability, 1)

assert assertion_probability == 7.8,\
    f'Incorrect Gaussian Probability calculated {assertion_probability}'

# %% [markdown]
# **The final step** is to go for each test point, calculate its posterior probability against each class, then classify it to the class with the highest posterior probability.

# %%
# TODO [7]: Apply the Bayesian Classifier to predict the classes of the test points.
predicted_classes = [] # predicted_classes: A numpy array of size (K, 1) where K is the number of points in the test set. Every element in this array
                       # contains the predicted class of Bayes classifier for this test point.

for i in range(X_Test.shape[0]):
    print("For test point:", X_Test[i])
    # TODO [7.A]: Compute the probability that the test point X_Test[i] belongs to each class in numClasses.
    classProbabilities = []
    #  Fill the array classProbabilities accordingly.
    classProbabilities.append([multivariate_normal_gaussian(X_Test[i], estimate_means[j], estimate_covariances[j]) * pClasses[j] for j in range(numClasses)])
    # TODO [7.B]: Find the prediction of the test point X_Test[i] and append it to the predicted_classes array.
    predicted_classes.append(np.argmax(classProbabilities) + 1)

    print('Class Probabilities: ', classProbabilities)  # the first class is the left most in the scatter plot
    print("Predicted class is :", predicted_classes[i])
    print("******************************************************************************")
# Out:
# For test point: [10.70141426  3.87253627]
# Class Probabilities:  [[2.389518415143048e-16, 1.9394007598019017e-05, 6.816471246931437e-06]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.81831787 -5.00977814]
# Class Probabilities:  [[0.0005803779352940714, 7.101752238663337e-15, 9.466018632392267e-07]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.57071936  9.96036181]
# Class Probabilities:  [[5.65799287010816e-12, 1.2144367146646677e-13, 4.124969853973243e-06]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.94309043 -0.01539406]
# Class Probabilities:  [[1.1370339463305137e-09, 0.008398271459652221, 0.0009560022695558362]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 4.26082551 -0.61349358]
# Class Probabilities:  [[3.7048906610796507e-09, 0.004365507977690782, 0.0008989169207111474]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.98901139 16.86268221]
# Class Probabilities:  [[8.970200343990342e-25, 6.64072347315219e-15, 3.5976042733569685e-11]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.2796485  -3.38655342]
# Class Probabilities:  [[8.750207202370458e-06, 8.077436840008074e-08, 8.034993745851559e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.60503344 -0.24206319]
# Class Probabilities:  [[7.476594969167931e-07, 0.0006516403108723898, 0.0019161293000309297]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.84312621 12.42130394]
# Class Probabilities:  [[5.816738623771278e-13, 5.254300595292792e-08, 2.3044659530585505e-06]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-6.52253054 10.13668928]
# Class Probabilities:  [[1.3467520029619128e-15, 9.579850426651208e-21, 6.036393963665973e-08]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 5.59472055 -4.37938379]
# Class Probabilities:  [[1.274658356538777e-15, 0.0006857527476492805, 6.694970977254587e-06]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.98596817 -0.73837508]
# Class Probabilities:  [[0.004956178965388713, 1.3874235148946514e-11, 0.00019061698907790652]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-2.23908496 13.21358765]
# Class Probabilities:  [[1.0398170634594455e-16, 9.594927472379484e-13, 8.949561900690482e-08]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -6.7789975 -11.0163502]
# Class Probabilities:  [[3.2244981725351686e-07, 1.663022074690602e-26, 1.8322862298782725e-13]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.59545273 -0.41955489]
# Class Probabilities:  [[5.3292386918954874e-05, 7.451846318985983e-06, 0.0016011799836142132]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.36129364 -5.42102971]
# Class Probabilities:  [[1.3312403269411797e-23, 5.7102973297241735e-05, 8.487513687735642e-08]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.52848225 -7.42893531]
# Class Probabilities:  [[4.1293464176949516e-07, 1.4283810296639278e-13, 4.727788148659325e-08]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.56086046 -9.03278997]
# Class Probabilities:  [[7.586941050713816e-07, 4.772253543360901e-19, 3.015714782669226e-10]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.02188067 -0.93735269]
# Class Probabilities:  [[6.429111064936499e-14, 0.005017955361137781, 9.957439954728914e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [9.1509862  1.43750612]
# Class Probabilities:  [[1.796383503702866e-15, 0.0007281729587556656, 3.889800182474505e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.71007022 10.6797775 ]
# Class Probabilities:  [[1.102076248710758e-11, 1.5906773112719659e-10, 8.681762217555339e-06]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.76302456 -5.55297678]
# Class Probabilities:  [[0.0010068188894586387, 2.482016623177858e-17, 1.569769875261609e-07]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.89883417 -5.39496672]
# Class Probabilities:  [[0.0014556598454983625, 1.405971651334387e-17, 1.7117067526287866e-07]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.03379007 2.71590677]
# Class Probabilities:  [[1.7690862386718263e-12, 0.003713840935168657, 0.00021805196199379176]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.89215726 -2.59460822]
# Class Probabilities:  [[0.011858478367681075, 2.466524610024207e-16, 5.771794301335982e-06]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.11834647  4.91066223]
# Class Probabilities:  [[1.0137869366739423e-05, 1.452022387360016e-13, 0.00014834123776872457]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 6.45717699 -2.43934454]
# Class Probabilities:  [[1.2274554390226763e-14, 0.0029267986583071566, 3.930130051862121e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.56547098 4.9207542 ]
# Class Probabilities:  [[1.2492740222611986e-05, 0.00011467766222486464, 0.004780272820123549]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [1.26265631 6.5794146 ]
# Class Probabilities:  [[2.2289285225723443e-06, 2.9819291222255895e-05, 0.002137308429508296]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.70832433 -3.11174424]
# Class Probabilities:  [[3.7138927565233555e-09, 0.00014371251128446948, 0.00013648736101185786]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ -9.10836917 -11.76552446]
# Class Probabilities:  [[1.6967859824982745e-06, 1.4951672827051077e-34, 5.925038324393162e-16]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.81726658 -5.3687788 ]
# Class Probabilities:  [[0.0013653335061201968, 2.291964847591999e-17, 1.9547001666314188e-07]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.30975347  9.75343174]
# Class Probabilities:  [[1.3074652289385578e-09, 4.5862933751066596e-08, 6.973768454193538e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.58893623 -3.93631034]
# Class Probabilities:  [[0.016156297551326738, 3.0233852175711105e-24, 2.8677097841452764e-08]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-11.3843618 -12.1472865]
# Class Probabilities:  [[5.46076218939849e-06, 2.6361809134997343e-43, 2.053653079723427e-18]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.15303864 -5.99521012]
# Class Probabilities:  [[1.981509540782487e-19, 0.00013487247269141405, 3.2647038791013374e-07]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [0.88072334 9.72115039]
# Class Probabilities:  [[3.1179777160157127e-09, 1.2156317936984861e-06, 0.00011445137694936554]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [1.3263618 8.7977202]
# Class Probabilities:  [[3.4321878522550165e-08, 7.71154747291421e-06, 0.00035259259662244246]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.70501109 11.56174259]
# Class Probabilities:  [[3.932479849515765e-16, 8.151503503380106e-17, 1.055566856711395e-07]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.12643357 -4.83616859]
# Class Probabilities:  [[0.00025298920719129045, 2.525755555777833e-13, 2.261707511267904e-06]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 4.05674244 12.57155861]
# Class Probabilities:  [[2.1747516094398053e-12, 6.598006653215174e-06, 1.9258923673949003e-06]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ -4.30106198 -10.6042502 ]
# Class Probabilities:  [[4.200342840517221e-09, 1.1635721784688058e-19, 1.0151501784960051e-11]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 5.11776496 -0.99143917]
# Class Probabilities:  [[9.757289869751978e-11, 0.006152022663782715, 0.00042441447629146603]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 6.05493358 -5.87189841]
# Class Probabilities:  [[5.4036287938306435e-19, 0.0001558615480453937, 4.393116510868311e-07]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.74275953 -3.97527522]
# Class Probabilities:  [[1.0611399290356243e-11, 0.00029496789059938654, 3.365990269819243e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.02170247 -5.57244813]
# Class Probabilities:  [[0.0003493165053322392, 1.2959659459461655e-15, 3.334469406612276e-07]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.27810154 -3.99998321]
# Class Probabilities:  [[0.007852752839569984, 7.549469865050593e-18, 7.466011892259503e-07]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.80988364 3.43699512]
# Class Probabilities:  [[5.2423370542061545e-09, 0.01343502810465113, 0.001697908420065401]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [8.6311676  1.76165524]
# Class Probabilities:  [[3.259048846596503e-14, 0.0017165295149753198, 8.510350430682651e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.73761305 -6.16978647]
# Class Probabilities:  [[0.0003997768878106579, 1.3119650328923527e-17, 6.029991973226908e-08]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [13.28411495 -2.28452888]
# Class Probabilities:  [[6.97779324767045e-31, 2.337947313045203e-09, 1.8043294724059988e-09]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.47775397 -0.10213091]
# Class Probabilities:  [[0.0034385504303430974, 1.8053441298215795e-10, 0.00042863543637150584]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.42758688 -7.1513932 ]
# Class Probabilities:  [[4.32747498932472e-05, 1.8715218012577137e-17, 1.518536117803999e-08]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.71805696 -8.49355483]
# Class Probabilities:  [[2.231235312524613e-09, 8.76411750500808e-13, 9.169497674407458e-09]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.07056432 13.27106731]
# Class Probabilities:  [[5.756117726519492e-19, 2.50876737336108e-16, 1.1825061289404046e-08]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.82594718 -9.52426172]
# Class Probabilities:  [[2.2969185451172516e-09, 1.3289075450021796e-15, 4.693969523093162e-10]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.2893587   1.35319816]
# Class Probabilities:  [[7.73126574751575e-18, 7.061815096756024e-05, 7.459436681967803e-06]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.13419282  9.00152907]
# Class Probabilities:  [[5.659601974608197e-09, 6.05637638505482e-09, 0.00010417969753399235]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.29226867  7.97517886]
# Class Probabilities:  [[1.5296040909111358e-07, 2.049449091110012e-07, 0.00045578163437206057]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 9.46997908 -1.99299457]
# Class Probabilities:  [[2.1908152002735868e-20, 0.0001453232970790736, 2.03497066567133e-06]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.05416915 -2.47425901]
# Class Probabilities:  [[0.00015209680583557714, 1.2092854071643563e-08, 0.0001601851186552331]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.21553241 12.53863186]
# Class Probabilities:  [[1.2883462756885149e-12, 7.431302104392586e-07, 2.450228260752589e-06]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.85953786 -0.76518719]
# Class Probabilities:  [[2.474431644089718e-17, 0.0007242068897390402, 1.4592069948363308e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 4.11560394 -2.51521659]
# Class Probabilities:  [[1.1824743841842118e-10, 0.0013541357336958088, 0.00016972231127360276]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.88633577 -7.73994173]
# Class Probabilities:  [[0.0001408946095800557, 1.6764073451813286e-21, 9.044823789426504e-10]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.79933965  5.31322455]
# Class Probabilities:  [[2.148595252275149e-05, 4.190121690639646e-09, 0.0010650501489576176]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.34271378 16.23529621]
# Class Probabilities:  [[1.0681266140792801e-19, 3.922137426744076e-10, 1.1274702623241086e-09]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.55913997 10.48707791]
# Class Probabilities:  [[5.061099725931319e-10, 2.574198412797676e-06, 5.053135421238082e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.86122888  7.15903434]
# Class Probabilities:  [[4.200363585842125e-07, 1.4871002438746763e-09, 0.0003447912127465018]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.38794864  4.18558645]
# Class Probabilities:  [[7.69367165951526e-05, 5.874626306155141e-12, 0.00039841284241379633]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-9.52727338 -7.21208436]
# Class Probabilities:  [[0.0035957099511203525, 2.1271054785530355e-32, 6.268014564907269e-12]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.98956144 -7.5666012 ]
# Class Probabilities:  [[4.9774072308422536e-05, 4.482873484844887e-19, 3.774707000410599e-09]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.75405923 -5.30192282]
# Class Probabilities:  [[0.010592830203466023, 1.2688930262816593e-28, 6.052235947717687e-10]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.94621632 -6.88516599]
# Class Probabilities:  [[3.070403656494917e-05, 3.464722567375952e-16, 3.990960517395819e-08]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.31994442 -2.63044722]
# Class Probabilities:  [[0.014186682065506303, 2.0944263648442125e-17, 3.3053304059935485e-06]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-9.36297948 -8.56822792]
# Class Probabilities:  [[0.0008590198517486367, 8.997933417553573e-33, 6.420351842683553e-13]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.81585174 -3.0905699 ]
# Class Probabilities:  [[0.004167370684166622, 4.919417782884849e-14, 1.0981366534214384e-05]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [11.48384894 -2.13782697]
# Class Probabilities:  [[1.309743757604713e-25, 1.0974540087555488e-06, 7.014926407893315e-08]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [7.38337554 4.66707989]
# Class Probabilities:  [[1.2628497663429544e-10, 0.00475557766061214, 0.0004156498073848146]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.19811716 -3.20869437]
# Class Probabilities:  [[0.0019020543820294738, 9.011710881695055e-13, 1.703607471971627e-05]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.73664819 -5.64026754]
# Class Probabilities:  [[0.0008653555782561402, 2.581817379451162e-17, 1.4124335061626588e-07]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.16135146 8.11909452]
# Class Probabilities:  [[7.982068709181206e-09, 0.0013928832428107235, 0.0003515300805972817]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.93192373 -7.90304636]
# Class Probabilities:  [[2.2617130274667346e-05, 3.73027734795399e-19, 2.0994258668637208e-09]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.44663034 -1.10812617]
# Class Probabilities:  [[6.598883462213114e-17, 0.0011527822037754824, 1.8304257175534754e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-10.41266737  -6.02755366]
# Class Probabilities:  [[0.004801371153239677, 7.713515526772691e-35, 7.410999712934872e-12]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-10.55452885  -6.98597699]
# Class Probabilities:  [[0.003369748937951836, 5.826261269356595e-36, 1.1232340400945784e-12]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.16708742 -4.41114641]
# Class Probabilities:  [[1.0137913813991532e-06, 4.454257430518679e-08, 2.2241861761103563e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [6.83499316 3.0513492 ]
# Class Probabilities:  [[1.7303018918733187e-10, 0.010312273650968725, 0.0007453514214196081]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.3218284   8.03062152]
# Class Probabilities:  [[1.3238073090906403e-07, 1.8015710354342557e-07, 0.0004277626163757713]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.67262506 -3.63638033]
# Class Probabilities:  [[0.0005948116367849861, 6.802720444034236e-12, 1.5865043950250646e-05]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.23839346 15.50904654]
# Class Probabilities:  [[2.8060794616403597e-18, 1.1550802384609727e-09, 5.897646682997083e-09]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.85415463 -9.49083878]
# Class Probabilities:  [[4.510630095552277e-12, 4.567763372621075e-12, 1.4999244819380617e-09]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.57934474 14.05416562]
# Class Probabilities:  [[7.91978690449647e-17, 1.0303977138031585e-10, 5.9405720718241217e-08]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [1.08121918 9.02118593]
# Class Probabilities:  [[1.973113358711518e-08, 3.670545317793974e-06, 0.0002654580509658921]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.54545494 13.38470402]
# Class Probabilities:  [[1.5053775511453285e-18, 2.6670310887142877e-15, 1.7551547217228672e-08]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.25685021 12.98458764]
# Class Probabilities:  [[3.2130649452988545e-14, 5.517404873533712e-09, 6.946005292895165e-07]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.49117921 -2.09111202]
# Class Probabilities:  [[2.4982070515969262e-18, 0.0006677940333024026, 6.705714868138572e-06]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [9.6377611  2.59220877]
# Class Probabilities:  [[2.329543908417042e-15, 0.0002866903534241017, 2.8936778431811078e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 7.99632131 -0.81831291]
# Class Probabilities:  [[1.2188290258843936e-15, 0.0022640699067042603, 3.9695544127307385e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 2.8066989  12.60496257]
# Class Probabilities:  [[1.4419631001453182e-12, 1.681913829990296e-06, 2.2057040148893883e-06]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.14054117 13.99755821]
# Class Probabilities:  [[2.3556846592535606e-16, 4.1907619513629054e-10, 8.463302173475666e-08]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.0622924  -4.14345298]
# Class Probabilities:  [[0.0005848906770668348, 7.066250603804711e-13, 6.140618690910663e-06]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.73588097 -8.59503648]
# Class Probabilities:  [[2.027070447935132e-05, 1.0817367588852943e-21, 1.970969022804221e-10]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.87691909 -8.51465367]
# Class Probabilities:  [[5.2204270547218424e-06, 1.9322717483446355e-19, 6.468307447872182e-10]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.30461631 -2.42881748]
# Class Probabilities:  [[2.0777129457784014e-18, 0.0006994759533802549, 5.835219880708471e-06]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.92551153  9.38904848]
# Class Probabilities:  [[6.88918614073952e-10, 2.385391496089434e-10, 3.852564493222733e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-8.06681967 -9.76445434]
# Class Probabilities:  [[4.4472686819033216e-05, 2.2167774620622047e-29, 4.998671382417054e-13]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.24410989 -8.18831047]
# Class Probabilities:  [[0.0007886411567506228, 9.267639855717345e-29, 1.0609032459663723e-11]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.37602904 -5.99069434]
# Class Probabilities:  [[0.001175958122493955, 4.296223020394484e-19, 3.825080326113743e-08]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.22386765 -4.85135398]
# Class Probabilities:  [[6.118067371613348e-12, 6.64835586697532e-05, 1.1615310336808302e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.55406083 -2.89224039]
# Class Probabilities:  [[1.95299814448242e-07, 1.7931960701210365e-05, 0.00019607256123273212]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.69049165 13.4044702 ]
# Class Probabilities:  [[8.908924093212573e-14, 4.5881704778364546e-07, 5.351115644711972e-07]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.53571156 10.66187251]
# Class Probabilities:  [[2.8703708565020893e-12, 6.148384940281413e-12, 4.486424641643729e-06]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.96782552 -4.31305255]
# Class Probabilities:  [[1.6543106308096954e-12, 0.00027646974929642314, 1.9214254236741607e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.00081432  8.87275799]
# Class Probabilities:  [[3.201758946984202e-09, 2.7223344274003766e-10, 6.470660891830268e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.35696677 -3.77423836]
# Class Probabilities:  [[0.009504876815328779, 5.9783732876841035e-18, 8.932940396244456e-07]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.48811048 -3.16156655]
# Class Probabilities:  [[1.0121869553724349e-17, 0.001004455254604496, 6.221135743845998e-06]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ -6.06573364 -13.36721214]
# Class Probabilities:  [[2.929288369684814e-11, 1.1023595299180684e-26, 7.676207797764575e-16]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.1851141 2.6171304]
# Class Probabilities:  [[1.5627239004379016e-08, 0.01348029600166537, 0.002357233007299394]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [8.27828524 1.31354615]
# Class Probabilities:  [[5.726225338807053e-14, 0.002722876204478634, 0.00010863194480213762]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [3.79242965 1.64031539]
# Class Probabilities:  [[2.648519389113899e-07, 0.0051935191857505145, 0.003564130021785902]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.138666   6.8602675]
# Class Probabilities:  [[1.737713817933534e-06, 6.473294383183848e-07, 0.001171340553522829]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 5.78244942 -9.12198008]
# Class Probabilities:  [[8.334398570241407e-25, 2.001853460577389e-06, 7.816618565470972e-10]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.60435329 -5.38072375]
# Class Probabilities:  [[2.552806785272769e-13, 6.304626849700259e-05, 4.466293622861841e-06]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.85525938 -6.34543458]
# Class Probabilities:  [[7.303126024378187e-05, 1.1468394431521357e-15, 1.1165451220187048e-07]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [13.08621387  1.9348786 ]
# Class Probabilities:  [[1.6720581135868244e-23, 1.3299653744965424e-08, 6.656723640499884e-08]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.97701781 -8.26247269]
# Class Probabilities:  [[1.5075267331758687e-06, 3.8191797575491537e-17, 2.753197416571368e-09]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.3366769  1.22185752]
# Class Probabilities:  [[0.0001819423947133359, 6.297703434396549e-06, 0.003463428549256798]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-9.28532526 -9.4355402 ]
# Class Probabilities:  [[0.00023448837247584466, 3.643651886024771e-33, 1.1833244562339585e-13]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.66429005 11.01189494]
# Class Probabilities:  [[1.170854009080653e-10, 1.7916172091336406e-06, 2.496255932508597e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.08966182 -1.69228564]
# Class Probabilities:  [[0.004381136615391655, 4.8391514615587505e-12, 8.402002150801154e-05]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.33789356 -2.66619436]
# Class Probabilities:  [[1.063751388625334e-14, 0.0026052341115858964, 3.3806573724531595e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.56901228  5.51033591]
# Class Probabilities:  [[1.8062338222298625e-05, 3.09806770869553e-07, 0.0020491514197357613]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.99286099 -4.68078563]
# Class Probabilities:  [[2.4281654120381453e-11, 5.618087868407881e-05, 1.600838495463581e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.80021733 11.42437424]
# Class Probabilities:  [[5.640270502035969e-13, 5.029504449641502e-11, 2.714676583564618e-06]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.16929961 -4.74585978]
# Class Probabilities:  [[1.059933498228362e-08, 1.3699641737685638e-06, 1.7632367702836397e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.15245262 14.77479741]
# Class Probabilities:  [[1.1929451231626512e-17, 2.813650618869911e-10, 1.9693331128129092e-08]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-11.57247905  -6.73922446]
# Class Probabilities:  [[0.0019451412866434887, 1.035999827626041e-39, 1.7340455925340445e-13]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.60476346  4.55773513]
# Class Probabilities:  [[3.6417118080690788e-06, 4.5902093350937427e-17, 2.5814337370089307e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.91493717 -4.93203896]
# Class Probabilities:  [[1.341523431521911e-21, 0.00015339313989415752, 3.208357438674636e-07]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.40280867 -4.97280708]
# Class Probabilities:  [[0.003919641986138226, 1.270140772443546e-18, 1.739239441772885e-07]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [2.04297042 2.03014309]
# Class Probabilities:  [[1.424685120612328e-05, 0.000409713308904589, 0.005456694046163166]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -6.21122011 -10.70086807]
# Class Probabilities:  [[2.591930060331182e-07, 1.26314169309341e-24, 8.795672067230287e-13]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.53064612 -8.83892725]
# Class Probabilities:  [[8.263111490515649e-06, 2.4971921307001345e-21, 1.5211410376602154e-10]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.30022088 11.20197432]
# Class Probabilities:  [[9.871501277380866e-11, 1.8746117044070938e-05, 1.906248304047389e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.52678262 11.00539841]
# Class Probabilities:  [[5.530770672272713e-11, 1.334269354148792e-07, 1.893176233476362e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [6.2375991  2.80421505]
# Class Probabilities:  [[8.714491594130357e-10, 0.013544395493738101, 0.0011861849911942177]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-7.1883182  -1.89030168]
# Class Probabilities:  [[0.011381826860536667, 2.9858998268036806e-22, 4.5044119667347934e-07]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.60122702 15.01466265]
# Class Probabilities:  [[8.007474567181891e-19, 2.105129348374718e-11, 7.851443447682649e-09]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.34641109 -4.86072033]
# Class Probabilities:  [[7.3311164320393204e-06, 4.662175458302364e-10, 7.25589890952451e-06]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.63822042 -5.45296469]
# Class Probabilities:  [[1.463699670959005e-19, 0.00021837854672178018, 5.304500646431027e-07]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [6.54807184 1.19913258]
# Class Probabilities:  [[3.596064206417581e-11, 0.011631142788748836, 0.0005862209287085179]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [11.7595198   0.33353443]
# Class Probabilities:  [[2.0134007132346357e-22, 1.1528745870853763e-06, 3.7134342390086747e-07]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [10.04384705  3.3153199 ]
# Class Probabilities:  [[1.5448988410176707e-15, 0.00010855118348689079, 1.805863732313905e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [3.72322077 2.89573292]
# Class Probabilities:  [[6.784056995992017e-07, 0.005033529664874003, 0.0047097455411553085]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.23412033 10.5086633 ]
# Class Probabilities:  [[1.4324730391641604e-13, 2.8144500659572103e-15, 9.228666646360895e-07]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.75812898 9.80988701]
# Class Probabilities:  [[3.1853048122987245e-09, 4.19717581753962e-05, 0.00012566919934887]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [5.71709878 0.05250004]
# Class Probabilities:  [[9.089343573432547e-11, 0.010413009976144718, 0.0006082817508806272]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.4383003  14.46253234]
# Class Probabilities:  [[2.9117089148296543e-22, 7.119048086806949e-18, 6.783977508357699e-10]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.31980548  5.65793048]
# Class Probabilities:  [[1.2821817725756077e-14, 2.447980607632827e-05, 8.883936054298517e-06]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-10.37524372  -7.74958537]
# Class Probabilities:  [[0.002234427196651196, 8.254385746419467e-36, 4.1398473682030435e-13]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.60020077 -5.42453553]
# Class Probabilities:  [[0.0009705458504787505, 7.119016895257303e-17, 2.2890957626868632e-07]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.20850522 -0.73094364]
# Class Probabilities:  [[7.433918636239324e-08, 0.0013222263106336782, 0.0012017553682741261]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.67511969 -0.45766944]
# Class Probabilities:  [[1.4229489648885485e-16, 0.0010695351217591663, 2.349809112356356e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.84241029 -2.07200837]
# Class Probabilities:  [[0.002859928252652201, 1.1528479381684874e-11, 7.381575091205837e-05]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.02815393 0.12504483]
# Class Probabilities:  [[1.08984376845155e-09, 0.009106300998580407, 0.000993487208336406]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.63527967 10.82193815]
# Class Probabilities:  [[2.0141410190460465e-10, 2.091152204101132e-06, 3.245720049827356e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [4.69546404 1.63793279]
# Class Probabilities:  [[2.3991067162200587e-08, 0.01059739570594248, 0.002426774837912452]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.20495861 -8.54182529]
# Class Probabilities:  [[1.2331176671090334e-06, 7.378399093973768e-18, 1.2377225719181142e-09]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.85664823  8.27107861]
# Class Probabilities:  [[2.1550382052422736e-11, 2.3495928128520183e-18, 1.530604195125963e-06]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.43266395 -7.3131535 ]
# Class Probabilities:  [[0.00016005188403491027, 4.958233312960829e-20, 3.598696727281273e-09]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.43743782 10.57358038]
# Class Probabilities:  [[4.673043254980576e-10, 4.47097631445815e-05, 4.438334968534235e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.51691079 1.90895905]
# Class Probabilities:  [[5.136975189917202e-08, 0.009748877972640691, 0.00287558899313614]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 2.95393725 -2.06290005]
# Class Probabilities:  [[1.5489381875057055e-08, 0.0004455761669868904, 0.00040301611571251473]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.17022706 -4.71914956]
# Class Probabilities:  [[5.4000139863728046e-05, 2.025640955362088e-11, 5.4729813938456935e-06]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [6.87943361 0.56763302]
# Class Probabilities:  [[3.361636132580823e-12, 0.008859394609482894, 0.0003211342104541669]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.90155375 -2.49446135]
# Class Probabilities:  [[7.668638327430586e-20, 0.000289398333657575, 2.5541719334883422e-06]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.75309704 10.13350214]
# Class Probabilities:  [[9.287513089735857e-10, 5.953901415185917e-07, 6.63360995306859e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-6.83046209 -9.95463151]
# Class Probabilities:  [[5.43712420762581e-06, 9.083407610155384e-26, 2.22506856646024e-12]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.48084666 2.21690041]
# Class Probabilities:  [[6.360695210800818e-12, 0.006781196533693141, 0.00035068494628568575]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.51484158 16.05856446]
# Class Probabilities:  [[6.717135445826645e-25, 4.65963004806111e-17, 5.622877780750818e-11]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.29796106 -1.51960377]
# Class Probabilities:  [[0.0020884901704752343, 1.8086177072041893e-10, 0.00018218912453467652]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.04675075 14.39325425]
# Class Probabilities:  [[3.013478243715322e-16, 4.8414818162914445e-09, 6.146765254854032e-08]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.33223697 -7.63241344]
# Class Probabilities:  [[1.6774538643170774e-06, 2.5502544937576217e-15, 1.721427632073853e-08]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.38944943 -9.23325113]
# Class Probabilities:  [[3.044794823365538e-07, 8.644538437916415e-19, 2.315536016940588e-10]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.74176393 -5.02512921]
# Class Probabilities:  [[0.0018890719579316832, 5.2187474486643554e-17, 3.5344897302713556e-07]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-7.41004634 -5.5997003 ]
# Class Probabilities:  [[0.008130235757741987, 1.5473283702371128e-24, 3.957735483554751e-09]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.09797276 -7.51282903]
# Class Probabilities:  [[0.0017578389812222543, 7.910642196865646e-28, 4.996296747538068e-11]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.65055    14.73266536]
# Class Probabilities:  [[1.6817326310551537e-16, 1.0000194825323216e-08, 3.523536689364916e-08]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [1.15219027 3.63873026]
# Class Probabilities:  [[4.457675357812037e-05, 5.920249824033253e-05, 0.0058008876952894625]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.25543293  9.24132191]
# Class Probabilities:  [[2.450439735000786e-09, 3.242215721150966e-09, 7.386520988872946e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.3701864  10.61688349]
# Class Probabilities:  [[4.6030897577965874e-12, 1.2763032615185752e-11, 5.536074735694257e-06]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-11.26329666  -7.92344489]
# Class Probabilities:  [[0.0015327247717588056, 2.675498458953535e-39, 4.245140002104353e-14]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [1.37598504 5.76529642]
# Class Probabilities:  [[6.212304809357396e-06, 5.6229258358047677e-05, 0.0033745705013813513]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.88140712 -3.02402962]
# Class Probabilities:  [[0.0046467815963734315, 3.742615098740533e-14, 1.1070378359968092e-05]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.66886091 -1.94857083]
# Class Probabilities:  [[0.006536400307285605, 2.5294341614176234e-13, 3.9528605441234445e-05]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.21817753 10.22511294]
# Class Probabilities:  [[4.903382346309932e-10, 1.3391200150526592e-07, 4.885029268078597e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.01734447 -3.01633766]
# Class Probabilities:  [[1.662822229954299e-09, 0.0002514882984306756, 0.0001422325428270926]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [2.45242039 2.18725534]
# Class Probabilities:  [[7.009320855029693e-06, 0.0008727548725775496, 0.005512253951630501]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.81338366 -3.04810313]
# Class Probabilities:  [[3.041018085139973e-09, 0.000179108157781414, 0.00014385676307290837]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.35226244  7.94145336]
# Class Probabilities:  [[8.704199054858654e-08, 6.168353781406587e-09, 0.00025836768230955414]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.32479122 -9.12757714]
# ...
# For test point: [-4.06815545  9.53292586]
# Class Probabilities:  [[1.0326031547044025e-11, 1.5829463126129903e-14, 4.022923811365438e-06]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [7.34079799 3.06978894]
# Class Probabilities:  [[3.326971239417485e-11, 0.0072068422261863975, 0.0004680367061967706]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.64032058 12.0068455 ]
# Class Probabilities:  [[7.282955771101259e-14, 4.595182931337284e-11, 1.2162208624439378e-06]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [11.02141864 -0.12519999]
# Class Probabilities:  [[2.675420010394674e-21, 8.810761770294038e-06, 9.757472310442767e-07]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [2.83660161 7.63741536]
# Class Probabilities:  [[1.8258514221859647e-07, 0.00028918124655479146, 0.0010728875945164836]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.55253392 -2.86889414]
# Class Probabilities:  [[2.8479419189758617e-06, 1.4820635982784602e-06, 0.00018178736328038073]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.97166844 -3.22481456]
# Class Probabilities:  [[3.4107621909243394e-11, 0.0007028407366991306, 8.00258747147971e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.98490968 -4.84749576]
# Class Probabilities:  [[0.0001960939373925773, 4.827051778621855e-13, 2.500313323111705e-06]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.10588756 1.58507517]
# Class Probabilities:  [[3.015751850411444e-15, 0.0007945754213404454, 4.379680604688233e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 4.99945013 -3.95313184]
# Class Probabilities:  [[7.045276068477914e-14, 0.0008251156612431687, 1.8242628425131613e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.71883232 15.1537229 ]
# Class Probabilities:  [[2.9864783947378177e-17, 5.646127181317968e-09, 1.4481370959300816e-08]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.33163346  9.72288532]
# Class Probabilities:  [[1.4054304030116638e-09, 4.414794936350889e-08, 7.158968305777472e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [11.04296746  1.25113376]
# Class Probabilities:  [[1.4077640679269397e-19, 1.0392919225487335e-05, 2.145942206580208e-06]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.22009129  9.65386874]
# Class Probabilities:  [[1.8918184967932583e-09, 6.590007014386545e-08, 8.209975644171314e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.70876068  2.17594789]
# Class Probabilities:  [[0.000976852408682096, 7.939774573226608e-09, 0.001699574768010755]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [4.51045177 7.56673947]
# Class Probabilities:  [[3.554764235915824e-08, 0.0016243508770924227, 0.0007408153532837323]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.29825485 13.66342044]
# Class Probabilities:  [[1.0757178240003302e-16, 1.7120223935404828e-11, 8.039406300153647e-08]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-9.72864588 -6.0121161 ]
# Class Probabilities:  [[0.006628300933125872, 2.328194131553958e-32, 3.14874378671974e-11]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.48899942 17.98748437]
# Class Probabilities:  [[1.0857688068196596e-25, 1.2068766691692289e-13, 5.7198624924054105e-12]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.77337683  7.24172304]
# Class Probabilities:  [[6.658899680707374e-07, 7.076313440430535e-08, 0.0006531571509312922]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.05007773 15.12157932]
# Class Probabilities:  [[1.2634174159637887e-20, 1.1285697679541717e-13, 2.138050737328615e-09]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.79351842 -4.31693215]
# Class Probabilities:  [[0.0013308080105393781, 1.707717470902802e-14, 2.536758455141737e-06]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.23987052 0.84895898]
# Class Probabilities:  [[1.4539579796338689e-12, 0.00739543099431375, 0.000264947328499693]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-7.30596448 -3.23156572]
# Class Probabilities:  [[0.016761437879150833, 4.3063607903191754e-23, 1.0230606809973273e-07]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.28227684 -5.29628215]
# Class Probabilities:  [[0.0024903374301278804, 1.7607221535723825e-18, 1.2595382225940464e-07]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.84284999 -4.65776943]
# Class Probabilities:  [[6.10583011720139e-21, 0.00021332757597602244, 5.326915722063575e-07]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.36231452 14.65339584]
# Class Probabilities:  [[6.244160948004156e-20, 6.988003530675378e-14, 4.481884187917629e-09]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.11518005 -5.99608685]
# Class Probabilities:  [[0.0008539678103098124, 1.944972388147506e-18, 5.1943401805029764e-08]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.61237327 4.48009751]
# Class Probabilities:  [[1.983772438644082e-12, 0.0011647393269209611, 0.0001150612841011487]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.95457177 -2.6426557 ]
# Class Probabilities:  [[1.519924614790657e-06, 5.131253477819296e-06, 0.0002478326708673396]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.91149048 -9.43001297]
# Class Probabilities:  [[4.04010914602928e-06, 8.811346932859415e-23, 2.5888264381833647e-11]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.90520993  5.66899844]
# Class Probabilities:  [[1.1606330135306535e-07, 6.046426728803246e-18, 1.0488274958883612e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.82381941  9.48699204]
# Class Probabilities:  [[2.2770527288952616e-12, 3.2759191591143334e-16, 1.67005003611225e-06]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.51481518 -2.69629369]
# Class Probabilities:  [[6.424034524775292e-10, 0.0006267788015071453, 0.00017642044388381658]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 4.81850398 -1.42510573]
# Class Probabilities:  [[1.1327763370886978e-10, 0.004341409114733677, 0.0003493575445638214]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.32369809 -7.1393455 ]
# Class Probabilities:  [[5.165504919877094e-06, 5.435096441789434e-15, 4.408770951504615e-08]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.46861438 -1.4433357 ]
# Class Probabilities:  [[0.01365706623376902, 2.1399707534486765e-17, 7.853248500164186e-06]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.98740359 -5.57716425]
# Class Probabilities:  [[7.654303881640696e-06, 1.647924100013327e-11, 1.7041701617489313e-06]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [11.65009927  4.93480248]
# Class Probabilities:  [[2.1207157289756012e-17, 8.89035916309882e-07, 1.2786378624510241e-06]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.29799896 -4.9997967 ]
# Class Probabilities:  [[0.00346512932588228, 2.2746024292932428e-18, 1.9050028187513872e-07]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.39210413 -8.94948394]
# Class Probabilities:  [[0.0002728727028105673, 8.555014340476046e-30, 1.7202856641929736e-12]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.03147831 -1.78716335]
# Class Probabilities:  [[4.1878950146502595e-05, 7.06195385702123e-07, 0.00047531602989325317]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.24658383 -0.90643208]
# Class Probabilities:  [[2.6644813168860393e-14, 0.00437131637743262, 8.201824183094488e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.56004924 -1.02757626]
# Class Probabilities:  [[1.6142789873520782e-08, 0.0017995829289700219, 0.0008597055012685843]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 7.36264317 -0.22355351]
# Class Probabilities:  [[8.770514146810498e-14, 0.005146485425128614, 0.0001229296770913327]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.87468243  1.68851414]
# Class Probabilities:  [[0.002026740491638007, 4.949113372431534e-13, 0.0002445531805625031]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.71271544 -9.47990792]
# Class Probabilities:  [[8.73453323856634e-11, 1.7645099486352605e-13, 1.0454624901865774e-09]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-6.79673036 -6.33979581]
# Class Probabilities:  [[0.0029449059989811155, 3.7481207436513547e-23, 3.1422814331797567e-09]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.06008745 9.97311029]
# Class Probabilities:  [[9.217535336006255e-10, 1.1033231732474072e-07, 6.304910801449882e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.82746067 -3.56345126]
# Class Probabilities:  [[0.007449566695939147, 1.5023595893266847e-16, 2.173620549570941e-06]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-7.90632459 -9.21895769]
# Class Probabilities:  [[0.00010788347425514135, 1.9096760471109366e-28, 2.198290955464828e-12]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.36874346 0.62545597]
# Class Probabilities:  [[5.591726421264852e-13, 0.006405658081352651, 0.00020744066287716782]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.22552188 -0.20662172]
# Class Probabilities:  [[2.1796878931225735e-15, 0.0021388814621684732, 4.863770168078002e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.20850538 -2.82403166]
# Class Probabilities:  [[5.717200586463713e-07, 8.425244714811816e-06, 0.0002085042236531806]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.21579751 2.94840046]
# Class Probabilities:  [[1.983934883205228e-06, 0.0027674491464198103, 0.005424458848261713]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.20729307 -5.44771275]
# Class Probabilities:  [[1.5898278542415467e-05, 7.659721416364161e-12, 1.8117186897004957e-06]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.40036386 -5.32174925]
# Class Probabilities:  [[0.002724998092757591, 8.553820160149024e-19, 1.048529088309524e-07]]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.15531485 -4.12155615]
# Class Probabilities:  [[7.865692306111573e-07, 1.5937613091093299e-07, 3.605081670116169e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [9.22382129 5.71360307]
# Class Probabilities:  [[6.970275136789928e-13, 0.0002460234541545893, 3.950598568628788e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.63952042 -4.65786291]
# Class Probabilities:  [[2.032861287547443e-06, 7.334294192687107e-09, 1.3357323346806938e-05]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [9.15705042 1.29990602]
# Class Probabilities:  [[1.2869608477669252e-15, 0.0007127070940814564, 3.6372817362702386e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [10.95944226  1.34437573]
# Class Probabilities:  [[2.766475901801073e-19, 1.310604799326525e-05, 2.5722454457681116e-06]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [12.70138697  4.8417071 ]
# Class Probabilities:  [[1.3972457090716556e-19, 2.6905610124905504e-08, 1.911722045480474e-07]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.13412403 8.8823782 ]
# Class Probabilities:  [[1.6859541713283804e-11, 0.00013981078340197036, 1.7217120703330633e-05]]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.02416693 11.64233379]
# Class Probabilities:  [[1.5619377789974795e-13, 1.6546439073742166e-11, 1.6152526034040973e-06]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [1.06908312 1.27293507]
# Class Probabilities:  [[6.033374227917953e-05, 4.372725957737629e-05, 0.0041187415823973755]]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 9.66236602 -2.51130178]
# Class Probabilities:  [[1.1918081733372512e-21, 7.4932021512139e-05, 8.744515546141066e-07]]
# Predicted class is : 2
# ******************************************************************************

# %% [markdown]
# ### Accuracy Algorithm:
# 1. comparing the predicted class with the actual class(test_data_true)
# 2. if you found difference, increment counter
# 3. divide the counter by the total number of tests.
# 4. multiply by 100 to evalute the percentage.

# %%
# TODO [8]: Compute the accuracy of the generated Bayesian classifier 
# WITHOUT USING ANY FOR LOOPs.
# print (test_data_true.flatten())

# res = [ ]
# for i in range(len(predicted_classes)):
#     if( predicted_classes[i] == test_data_true[0][i]):
#         res.append(i)
# print ( res )
print(test_data_true.shape[1])
test_data_true = test_data_true.reshape(1, -1)
accuracy = np.sum(np.array([test_data_true]) == np.array(predicted_classes)) / len(test_data_true[0])
print('Accuracy = ' + str(round(accuracy,4) * 100) + '%')
# Out:
# 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\GitHub\FacultyOfEngineeringMaterial\ThirdYear\SecondTerm\Nural_Networks\Labs\Lab 3 - Bayes Classifier\Lab 3 - Bayesian Classifier.ipynb Cell 22 in <cell line: 11>()
#       <a href='vscode-notebook-cell:/c%3A/GitHub/FacultyOfEngineeringMaterial/ThirdYear/SecondTerm/Nural_Networks/Labs/Lab%203%20-%20Bayes%20Classifier/Lab%203%20-%20Bayesian%20Classifier.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> # TODO [8]: Compute the accuracy of the generated Bayesian classifier
#       <a href='vscode-notebook-cell:/c%3A/GitHub/FacultyOfEngineeringMaterial/ThirdYear/SecondTerm/Nural_Networks/Labs/Lab%203%20-%20Bayes%20Classifier/Lab%203%20-%20Bayesian%20Classifier.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> # WITHOUT USING ANY FOR LOOPs.
#       <a href='vscode-notebook-cell:/c%3A/GitHub/FacultyOfEngineeringMaterial/ThirdYear/SecondTerm/Nural_Networks/Labs/Lab%203%20-%20Bayes%20Classifier/Lab%203%20-%20Bayesian%20Classifier.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> # print (test_data_true.flatten())
#    (...)
#       <a href='vscode-notebook-cell:/c%3A/GitHub/FacultyOfEngineeringMaterial/ThirdYear/SecondTerm/Nural_Networks/Labs/Lab%203%20-%20Bayes%20Classifier/Lab%203%20-%20Bayesian%20Classifier.ipynb#X24sZmlsZQ%3D%3D?line=7'>8</a> #         res.append(i)
#       <a href='vscode-notebook-cell:/c%3A/GitHub/FacultyOfEngineeringMaterial/ThirdYear/SecondTerm/Nural_Networks/Labs/Lab%203%20-%20Bayes%20Classifier/Lab%203%20-%20Bayesian%20Classifier.ipynb#X24sZmlsZQ%3D%3D?line=8'>9</a> # print ( res )
#      <a href='vscode-notebook-cell:/c%3A/GitHub/FacultyOfEngineeringMaterial/ThirdYear/SecondTerm/Nural_Networks/Labs/Lab%203%20-%20Bayes%20Classifier/Lab%203%20-%20Bayesian%20Classifier.ipynb#X24sZmlsZQ%3D%3D?line=9'>10</a> print(test_data_true.shape[1])
# ---> <a href='vscode-notebook-cell:/c%3A/GitHub/FacultyOfEngineeringMaterial/ThirdYear/SecondTerm/Nural_Networks/Labs/Lab%203%20-%20Bayes%20Classifier/Lab%203%20-%20Bayesian%20Classifier.ipynb#X24sZmlsZQ%3D%3D?line=10'>11</a> test_data_true = test_data_true.reshape(1, -1)
#      <a href='vscode-notebook-cell:/c%3A/GitHub/FacultyOfEngineeringMaterial/ThirdYear/SecondTerm/Nural_Networks/Labs/Lab%203%20-%20Bayes%20Classifier/Lab%203%20-%20Bayesian%20Classifier.ipynb#X24sZmlsZQ%3D%3D?line=11'>12</a> accuracy = np.sum(np.array([test_data_true]) == np.array(predicted_classes)) / len(test_data_true[0])
#      <a href='vscode-notebook-cell:/c%3A/GitHub/FacultyOfEngineeringMaterial/ThirdYear/SecondTerm/Nural_Networks/Labs/Lab%203%20-%20Bayes%20Classifier/Lab%203%20-%20Bayesian%20Classifier.ipynb#X24sZmlsZQ%3D%3D?line=12'>13</a> print('Accuracy = ' + str(round(accuracy,4) * 100) + '%')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'

# %%
# TODO [9]: Generate a 3D-plot for the generated distributions. x-axis and y-axis represent the features of the data, 
#           where z-axis represent the Gaussian probability N at this point.

x = np.linspace(-10, 10, 300)
y = np.linspace(-10, 15, 300)
X, Y = np.meshgrid(x, y)
Z = np.zeros(X.shape)

for i in range(Z.shape[0]):
    for j in range(Z.shape[1]):
        # TODO [9]: Fill in the matrix Z which will represent the probability distribution of every point.
        # Z[i,j] represents the joint probability N(x,y) for x = i and y = j. 
        # We want to draw the gaussian probability N(x,y) for all points. 
        for k in range (numClasses):
            Z[i, j].append( multivariate_normal_gaussian(np.array([X[i, j], Y[i, j]]), estimate_means[k], estimate_covariances[k]))

# Make a 3D plot, do not change code
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis', linewidth=0)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\GitHub\FacultyOfEngineeringMaterial\ThirdYear\SecondTerm\Nural_Networks\Labs\Lab 3 - Bayes Classifier\Lab 3 - Bayesian Classifier.ipynb Cell 23 in <cell line: 9>()
#      <a href='vscode-notebook-cell:/c%3A/GitHub/FacultyOfEngineeringMaterial/ThirdYear/SecondTerm/Nural_Networks/Labs/Lab%203%20-%20Bayes%20Classifier/Lab%203%20-%20Bayesian%20Classifier.ipynb#X25sZmlsZQ%3D%3D?line=9'>10</a>     for j in range(Z.shape[1]):
#      <a href='vscode-notebook-cell:/c%3A/GitHub/FacultyOfEngineeringMaterial/ThirdYear/SecondTerm/Nural_Networks/Labs/Lab%203%20-%20Bayes%20Classifier/Lab%203%20-%20Bayesian%20Classifier.ipynb#X25sZmlsZQ%3D%3D?line=10'>11</a>         # TODO [9]: Fill in the matrix Z which will represent the probability distribution of every point.
#      <a href='vscode-notebook-cell:/c%3A/GitHub/FacultyOfEngineeringMaterial/ThirdYear/SecondTerm/Nural_Networks/Labs/Lab%203%20-%20Bayes%20Classifier/Lab%203%20-%20Bayesian%20Classifier.ipynb#X25sZmlsZQ%3D%3D?line=11'>12</a>         # Z[i,j] represents the joint probability N(x,y) for x = i and y = j.
#      <a href='vscode-notebook-cell:/c%3A/GitHub/FacultyOfEngineeringMaterial/ThirdYear/SecondTerm/Nural_Networks/Labs/Lab%203%20-%20Bayes%20Classifier/Lab%203%20-%20Bayesian%20Classifier.ipynb#X25sZmlsZQ%3D%3D?line=12'>13</a>         # We want to draw the gaussian probability N(x,y) for all points.
#      <a href='vscode-notebook-cell:/c%3A/GitHub/FacultyOfEngineeringMaterial/ThirdYear/SecondTerm/Nural_Networks/Labs/Lab%203%20-%20Bayes%20Classifier/Lab%203%20-%20Bayesian%20Classifier.ipynb#X25sZmlsZQ%3D%3D?line=13'>14</a>         for k in range (numClasses):
# ---> <a href='vscode-notebook-cell:/c%3A/GitHub/FacultyOfEngineeringMaterial/ThirdYear/SecondTerm/Nural_Networks/Labs/Lab%203%20-%20Bayes%20Classifier/Lab%203%20-%20Bayesian%20Classifier.ipynb#X25sZmlsZQ%3D%3D?line=14'>15</a>             Z[i, j].append( multivariate_normal_gaussian(np.array([X[i, j], Y[i, j]]), estimate_means[k], estimate_covariances[k]))
#      <a href='vscode-notebook-cell:/c%3A/GitHub/FacultyOfEngineeringMaterial/ThirdYear/SecondTerm/Nural_Networks/Labs/Lab%203%20-%20Bayes%20Classifier/Lab%203%20-%20Bayesian%20Classifier.ipynb#X25sZmlsZQ%3D%3D?line=16'>17</a> # Make a 3D plot, do not change code
#      <a href='vscode-notebook-cell:/c%3A/GitHub/FacultyOfEngineeringMaterial/ThirdYear/SecondTerm/Nural_Networks/Labs/Lab%203%20-%20Bayes%20Classifier/Lab%203%20-%20Bayesian%20Classifier.ipynb#X25sZmlsZQ%3D%3D?line=17'>18</a> fig = plt.figure()
#
# AttributeError: 'numpy.float64' object has no attribute 'append'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# How can you judge your plot is correct?
'''
    Your Answer:
    1. 
'''
